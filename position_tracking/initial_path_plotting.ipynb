# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import fastgif
import framemaker as fm

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("tracking_test_v2.csv")
df_id0 = df[df.id == 0]
df_id0.head()
# Out:
#                                        image_filename         x1         y1  \
# 0   /Users/jonathanzhu/nematostella_videos/imgs/rp...  460.43430  598.05660
# 23  /Users/jonathanzhu/nematostella_videos/imgs/rp...  460.46005  598.18445
# 45  /Users/jonathanzhu/nematostella_videos/imgs/rp...  460.53693  598.12730
# 67  /Users/jonathanzhu/nematostella_videos/imgs/rp...  460.49110  598.14950
# 90  /Users/jonathanzhu/nematostella_videos/imgs/rp...  460.54892  598.14360
#
#            x2         y2      conf  class     width    height    x_center  \
# 0   483.90400  611.14630  0.950165    1.0  23.46970  13.08970  472.169150
# 23  483.91800  611.26654  0.950953    1.0  23.45795  13.08209  472.189025
# 45  483.98163  611.17017  0.950343    1.0  23.44470  13.04287  472.259280
# 67  483.96863  611.24133  0.950709    1.0  23.47753  13.09183  472.229865
# 90  484.07602  611.14636  0.950103    1.0  23.52710  13.00276  472.312470
#
#       y_center  id
# 0   604.601450   0
# 23  604.725495   0
# 45  604.648735   0
# 67  604.695415   0
# 90  604.644980   0

# %%
ids = df["id"].unique()
df_individuals = []
for i in ids:
    df_individuals.append(df[df.id == i])

# %%
fastgif.make_gif(fm.get_frame, 1799, 'test.gif', show_progress=True, writer_kwargs={'duration': 0.01})
# Out:
# Collecting results and creating a gif:   0%|          | 0/1799 [00:00<?, ?it/s]

# %%
plt.plot(df_id0.x_center, df_id0.y_center)

# %%
ids = df["id"].unique()
df_individuals = []
for i in ids:
    df_individuals.append(df[df.id == i])
    plt.scatter(df_individuals[i].x_center, df_individuals[i].y_center)

# %%
for i in ids:
    df_individuals.append(df[df.id == i])
    plt.plot(df_individuals[i].x_center, df_individuals[i].y_center)
