# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("tracking_test.csv")
df_id0 = df[df.id == 0]
df_id0.head()
# Out:
#                                        image_filename in_filter         x1  \
# 0   /Users/jonathanzhu/nematostella_videos/imgs/rp...       0.0  460.43430
# 21  /Users/jonathanzhu/nematostella_videos/imgs/rp...       0.0  460.46005
# 41  /Users/jonathanzhu/nematostella_videos/imgs/rp...       0.0  460.53693
# 61  /Users/jonathanzhu/nematostella_videos/imgs/rp...       0.0  460.49110
# 82  /Users/jonathanzhu/nematostella_videos/imgs/rp...       0.0  460.54892
#
#            y1         x2         y2      conf  class     width    height  \
# 0   598.05660  483.90400  611.14630  0.950165    1.0  23.46970  13.08970
# 21  598.18445  483.91800  611.26654  0.950953    1.0  23.45795  13.08209
# 41  598.12730  483.98163  611.17017  0.950343    1.0  23.44470  13.04287
# 61  598.14950  483.96863  611.24133  0.950709    1.0  23.47753  13.09183
# 82  598.14360  484.07602  611.14636  0.950103    1.0  23.52710  13.00276
#
#       x_center    y_center  id
# 0   472.169150  604.601450   0
# 21  472.189025  604.725495   0
# 41  472.259280  604.648735   0
# 61  472.229865  604.695415   0
# 82  472.312470  604.644980   0

# %%
plt.plot(df_id0.x_center, df_id0.y_center)

# %%
ids = df["id"].unique()
df_individuals = []
for i in ids:
    df_individuals.append(df[df.id == i])
    plt.scatter(df_individuals[i].x_center, df_individuals[i].y_center)

# %%
for i in ids:
    df_individuals.append(df[df.id == i])
    plt.plot(df_individuals[i].x_center, df_individuals[i].y_center)
