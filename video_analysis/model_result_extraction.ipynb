# %%
import ultralytics
from ultralytics import YOLO
from PIL import Image, ImageDraw, ImageFont
import requests

import os
import cv2

from matplotlib import patches, text, patheffects
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import shutil
import yaml

ultralytics.checks()
# Out:
# Ultralytics 8.4.63 🚀 Python-3.13.1 torch-2.6.0 CPU (Apple M2 Pro)
# Setup complete ✅ (10 CPUs, 16.0 GB RAM, 307.0/460.4 GB disk)

# %%
#optional: a lot of warnings come up
import warnings
warnings.filterwarnings('ignore')

# %%
best_model = YOLO("runs/detect/train-4/weights/best.pt")

# %%
base_dir = "/Users/jonathanzhu/nematostella_videos/imgs/"
img_folders = os.listdir(base_dir)
img_folders
# Out:
# ['wt_25c_6_dpf_fert_04_10_2026',
#  'rpa_bb_16C_9_dpf_celldish_04_02_2026',
#  'rpa_bb_16C_3_dpf_movedtodish_03_27_2026',
#  'rpa_aa_16C_3_dpf_fert_04_24_2026',
#  'wt_25c_7_dpf_fert_04_10_2026',
#  'wt_16C_2_dpf_03_26_2026',
#  'rpa_bb_25C_8_dpf_celldish_04_01_2026',
#  'rpa_aa_25C_3_dpf_03_27_2026_celldish',
#  'rpa_bb_16C_3_dpf_fert_04_24_2026',
#  'glw_ac_16c_3_dpf_fert_04_24_2026',
#  'rpa_bb_16C_6_dpf_celldish_03_30_2026',
#  'wt_25c_4_dpf_fert_04_10_2026',
#  'wt_25C_6_dpf_celldish_03_30_2026',
#  'rpa_aa_16C_3_dpf_movedtodish_03_27_2026',
#  'wt_25c_5_dpf_fert_04_10_2026',
#  'wt_16C_8_dpf_celldish_04_01_2026',
#  'rpa_aa_16C_6_dpf_fert_04_24_2026',
#  'wt_16C_3_dpf_03_27_2026_celldish',
#  '.DS_Store',
#  'rpa_bb_16C_2_dpf_03_26_2026',
#  'rpa_aa_25C_8_dpf_celldish_04_01_2026',
#  'rpa_aa_16C_7_dpf_fert_04_24_2026',
#  'glw_ac_16c_5_dpf_fert_04_24_2026',
#  'rpa_bb_25C_3_dpf_03_27_2026_celldish',
#  'rpa_bb_16C_5_dpf_fert_04_24_2026',
#  'rpa_aa_16C_6_dpf_celldish_03_30_2026',
#  'rpa_bb_16C_6_dpf_fert_04_24_2026',
#  'glw_ac_16c_6_dpf_fert_04_24_2026',
#  'rpa_aa_25C_2_dpf_03_26_2026',
#  'rpa_aa_16C_9_dpf_celldish_04_02_2026',
#  'glw_ac_25C_2_dpf_03_26_2026',
#  'glw_ac_16c_7_dpf_fert_04_24_2026',
#  'rpa_aa_16C_5_dpf_fert_04_24_2026',
#  'rpa_bb_16C_7_dpf_fert_04_24_2026',
#  'rpa_aa_25C_3_dpf_fert_04_24_2026',
#  'wt_25C_8_dpf_celldish_04_01_2026',
#  'wt_16c_6_dpf_fert_04_10_2026',
#  'wt_16C_6_dpf_celldish_03_30_2026',
#  'rpa_bb_25C_6_dpf_celldish_03_30_2026',
#  'rpa_aa_16C_3_dpf_03_27_2026_celldish',
#  'rpa_bb_16C_8_dpf_celldish_04_01_2026',
#  'wt_16c_7_dpf_fert_04_10_2026',
#  'wt_16c_4_dpf_fert_04_10_2026',
#  'wt_16C_9_dpf_celldish_04_02_2026',
#  'wt_25C_2_dpf_03_26_2026',
#  'glw_ac_25c_3_dpf_fert_04_24_2026',
#  'rpa_bb_25C_3_dpf_fert_04_24_2026',
#  'wt_16c_5_dpf_fert_04_10_2026',
#  'glw_ac_16C_2_dpf_03_26_2026',
#  'rpa_aa_25C_4_dpf_fert_04_10_2026_take2',
#  'rpa_aa_16C_2_dpf_03_26_2026',
#  'rpa_aa_25C_6_dpf_fert_04_24_2026',
#  'rpa_bb_25C_5_dpf_fert_04_24_2026',
#  'glw_ac_25c_5_dpf_fert_04_24_2026',
#  'rpa_aa_25C_7_dpf_fert_04_24_2026',
#  'glw_ac_25c_6_dpf_fert_04_24_2026',
#  'rpa_aa_25C_6_dpf_celldish_03_30_2026',
#  'rpa_bb_25C_6_dpf_fert_04_24_2026',
#  'rpa_bb_16C_3_dpf_03_27_2026_celldish',
#  'rpa_aa_16C_8_dpf_celldish_04_01_2026',
#  'rpa_bb_25C_7_dpf_fert_04_24_2026',
#  'rpa_aa_25C_5_dpf_fert_04_24_2026',
#  'glw_ac_25c_7_dpf_fert_04_24_2026',
#  'rpa_bb_25C_2_dpf_03_26_2026',
#  'wt_16C_6_dpf_movedtodish_03_30_2026',
#  'wt_16c_5_dpf_fert_04_24_2026',
#  'wt_16c_6_dpf_fert_04_24_2026',
#  'wt_16c_7_dpf_fert_04_24_2026',
#  'glw_ac_25c_6_dpf_fert_04_10_2026',
#  'rpa_aa_25C_4_dpf_fert_04_10_2026',
#  'rpa_bb_25C_6_dpf_fert_04_10_2026',
#  'rpa_bb_25C_7_dpf_fert_04_10_2026',
#  'rpa_aa_25C_5_dpf_fert_04_10_2026',
#  'glw_ac_25c_7_dpf_fert_04_10_2026',
#  'wt_16C_3_dpf_movedtodish_03_27_2026',
#  'rpa_aa_25C_6_dpf_fert_04_10_2026',
#  'glw_ac_25c_4_dpf_fert_04_10_2026',
#  'rpa_bb_25C_4_dpf_fert_04_10_2026',
#  'wt_16c_3_dpf_fert_04_24_2026',
#  'wt_25C_3_dpf_celldish_03_27_2026',
#  'rpa_bb_25C_5_dpf_fert_04_10_2026',
#  'glw_ac_25c_5_dpf_fert_04_10_2026',
#  'rpa_aa_25C_7_dpf_fert_04_10_2026',
#  'glw_ac_16C_3_dpf_movedtodish_03_27_2026',
#  'wt_25c_5_dpf_fert_04_24_2026',
#  'rpa_bb_16C_6_dpf_movedtodish_03_30_2026',
#  'wt_25c_6_dpf_fert_04_24_2026',
#  'rpa_aa_16C_6_dpf_movedtodish_03_30_2026',
#  'wt_25c_7_dpf_fert_04_24_2026',
#  'rpa_bb_16C_6_dpf_fert_04_10_2026',
#  'rpa_aa_16C_4_dpf_fert_04_10_2026',
#  'glw_ac_16c_6_dpf_fert_04_10_2026',
#  'glw_ac_16c_7_dpf_fert_04_10_2026',
#  'rpa_aa_16C_5_dpf_fert_04_10_2026',
#  'rpa_bb_16C_7_dpf_fert_04_10_2026',
#  'wt_25c_3_dpf_fert_04_24_2026',
#  'rpa_bb_16C_4_dpf_fert_04_10_2026',
#  'glw_ac_16c_4_dpf_fert_04_10_2026',
#  'rpa_aa_16C_6_dpf_fert_04_10_2026',
#  'rpa_aa_16C_7_dpf_fert_04_10_2026',
#  'glw_ac_16c_5_dpf_fert_04_10_2026',
#  'rpa_bb_16C_5_dpf_fert_04_10_2026']

# %%
current_dir = base_dir + img_folders[1] #folder with the images
images_list = os.listdir(current_dir)
images_list = [current_dir + "/" + i for i in images_list]

# %%
df_full = pd.DataFrame() #the dataframe that contains everything from this stack

for img in images_list:
    results = best_model(img, verbose=False)
    for r in results:
        b = r.boxes.data  # Boxes object for bounding box outputs
        df_res = pd.DataFrame(np.array(b))
        df_res.columns = ["x1", "y1", "x2", "y2", "conf", "class"]
        df_res.insert(0, "image_filename", img)
        df_full = pd.concat([df_full, df_res], ignore_index=True)

df_full.to_csv(current_dir + "/positions.csv", index = False)
print("Saved to " + current_dir + "/positions.csv")
# Out:
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# ...
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# /var/folders/px/b7vc3nh913zb_m0x36ncftj00000gn/T/ipykernel_16893/1023369969.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   df_res = pd.DataFrame(np.array(b))
# Saved to /Users/jonathanzhu/nematostella_videos/imgs/rpa_bb_16C_9_dpf_celldish_04_02_2026/positions.csv
